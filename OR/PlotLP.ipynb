# %%
import matplotlib.pyplot as plt

# %%
demand = [2000, 2600, 3200, 3800, 4400, 5000]
revenue = [140400, 141600, 142800, 143400, 143400, 143400]

# %%
plt.plot(demand, revenue)
plt.xlabel('Demand PIII')
plt.ylabel('Revenue in 10k SEK')
plt.tight_layout()
plt.savefig('Task1_plot_P1')
