# %%
import matplotlib.pyplot as plt

# %%
demand = [2000, 3200, 17200, 20000]
revenue = [140400, 142800, 156800, 156800]

# %%
plt.plot(demand, revenue)
plt.xlabel('Demand PIII')
plt.ylabel('Profit in 10k SEK')
plt.tight_layout()
plt.savefig('Task1_plot_P1')
